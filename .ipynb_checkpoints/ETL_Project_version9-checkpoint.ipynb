# %% [markdown]
# # ETL Project
# ###
# ### Team 6 Project Members:  Nisha Saphota, Daniel Eddie, Jon Simpson, Rob Gauer
# ### Date Due:  Tuesday June 9, 2020

# %%
# Dependencies and Setup
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %% [markdown]
# ## Store CSV into DataFrame

# %%
# Create dataframe from Kaggle dataset
kaggle_csv_file = "./Resources/spotify_60k_kaggle_master_song.csv"
album_data_df = pd.read_csv(kaggle_csv_file)

# display the contents of the data frame 
album_data_df.head()
# Out:
#    Release Date                 Artist        Album                Track ID  \
# 0          2013  The Devil Wears Prada  0.345833333  56PpndWxF2IGNQeBATYEEl
# 1          2011               BeyoncÃ©            4  1uXbwHHfgsXcUKfSZw5ZJ0
# 2          1998          Lenny Kravitz            5  6vUoqsJ0uVBgSKaUAUEQYC
# 3          1998          Lenny Kravitz            5  0KF7XWr4IxZsmD1DnSkDwh
# 4          2000          Lenny Kravitz            5  2zee8Zcesqwnnwliw2Jy8M
#
#                    Track  Popularity  Danceability  Energy Key  Key Val  \
# 0                 Rumors          31         0.455   0.972   A        9
# 1  Run the World (Girls)          73         0.733   0.899   C        0
# 2                   Live          39         0.632   0.926   G        7
# 3       Supersoulfighter          30         0.747   0.868   B       11
# 4        I Belong To You          57         0.690   0.664   F        5
#
#    Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0    -3.025     1       0.1870      0.000193          0.000229     0.387
# 1    -4.237     1       0.1430      0.004960          0.000047     0.372
# 2    -5.954     1       0.1270      0.008900          0.466000     0.367
# 3    -6.360     0       0.0613      0.002470          0.174000     0.494
# 4    -7.715     0       0.0542      0.000447          0.034300     0.073
#
#    Valence    Tempo  Time Signature
# 0    0.102  133.034               4
# 1    0.760  127.086               4
# 2    0.777  168.284               4
# 3    0.485  110.950               4
# 4    0.630   87.287               4

# %%
# Create dataframe from Zenodo dataset
zenodo_csv_file = "./Resources/spotify_zenodo_output_data.csv"
album_reviews_all_columns_df = pd.read_csv(zenodo_csv_file)

# display the contents of the data frame 
album_reviews_all_columns_df.head()
# Out:
#            artist                              album        reviewauthor  \
# 0        Studio 1                           Studio 1      Andy Battaglia
# 1      John Fahey  The Great Santa Barbara Oil Slick     Mark Richardson
# 2  Reigning Sound                    Too Much Guitar  Stephen M. Deusner
# 3  The Red Thread                     After the Last        Chris Dahlen
# 4      Mac Miller                           Swimming      Evan Rytlewski
#
#    score  releaseyear        reviewdate   recordlabel         genre  \
# 0    8.5       2009.0  February 18 2009        Studio    Electronic
# 1    8.2       2005.0  February 13 2005         Water  Folk/Country
# 2    8.3       2004.0    August 19 2004    In the Red    Electronic
# 3    7.3       2003.0      July 17 2003        Badman          Rock
# 4    7.5       2018.0     August 3 2018  Warner Bros.           Rap
#
#    danceability    energy       key   loudness  speechiness  acousticness  \
# 0      0.511917  0.499667  5.250000  -5.626583     0.031983      0.724917
# 1      0.369765  0.325412  4.470588 -19.153824     0.148624      0.647053
# 2      0.253943  0.912857  4.428571  -1.089500     0.055500      0.000253
# 3      0.425400  0.433474  5.700000 -12.871000     0.028260      0.310325
# 4      0.624846  0.438154  4.153846  -9.456077     0.170246      0.652462
#
#    instrumentalness  liveness   valence       tempo
# 0          0.024493  0.165367  0.555083  101.395167
# 1          0.559133  0.527782  0.179465  107.622647
# 2          0.751214  0.199071  0.552786  133.895500
# 3          0.224137  0.125150  0.451400  104.354200
# 4          0.012819  0.121131  0.281138  122.121308

# %% [markdown]
# ## Review DataFrames and Prepare for Merge

# %%
# DataFrame 'album_data_df' change 'Album' and 'Artist' columns to all uppercase.
album_data_df['Album']=album_data_df['Album'].str.upper()
album_data_df['Artist']=album_data_df['Artist'].str.upper()

# display the contents of the data frame 
album_data_df.head()
# Out:
#    Release Date                 Artist        Album                Track ID  \
# 0          2013  THE DEVIL WEARS PRADA  0.345833333  56PpndWxF2IGNQeBATYEEl
# 1          2011               BEYONCÃ©            4  1uXbwHHfgsXcUKfSZw5ZJ0
# 2          1998          LENNY KRAVITZ            5  6vUoqsJ0uVBgSKaUAUEQYC
# 3          1998          LENNY KRAVITZ            5  0KF7XWr4IxZsmD1DnSkDwh
# 4          2000          LENNY KRAVITZ            5  2zee8Zcesqwnnwliw2Jy8M
#
#                    Track  Popularity  Danceability  Energy Key  Key Val  \
# 0                 Rumors          31         0.455   0.972   A        9
# 1  Run the World (Girls)          73         0.733   0.899   C        0
# 2                   Live          39         0.632   0.926   G        7
# 3       Supersoulfighter          30         0.747   0.868   B       11
# 4        I Belong To You          57         0.690   0.664   F        5
#
#    Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0    -3.025     1       0.1870      0.000193          0.000229     0.387
# 1    -4.237     1       0.1430      0.004960          0.000047     0.372
# 2    -5.954     1       0.1270      0.008900          0.466000     0.367
# 3    -6.360     0       0.0613      0.002470          0.174000     0.494
# 4    -7.715     0       0.0542      0.000447          0.034300     0.073
#
#    Valence    Tempo  Time Signature
# 0    0.102  133.034               4
# 1    0.760  127.086               4
# 2    0.777  168.284               4
# 3    0.485  110.950               4
# 4    0.630   87.287               4

# %%
# DataFrame 'album_reviews_all_columns_df' change 'Album' and 'Artist' columns to all uppercase.
album_reviews_all_columns_df['album']=album_reviews_all_columns_df['album'].str.upper()
album_reviews_all_columns_df['artist']=album_reviews_all_columns_df['artist'].str.upper()

# display the contents of the data frame 
album_reviews_all_columns_df.head()
# Out:
#            artist                              album        reviewauthor  \
# 0        STUDIO 1                           STUDIO 1      Andy Battaglia
# 1      JOHN FAHEY  THE GREAT SANTA BARBARA OIL SLICK     Mark Richardson
# 2  REIGNING SOUND                    TOO MUCH GUITAR  Stephen M. Deusner
# 3  THE RED THREAD                     AFTER THE LAST        Chris Dahlen
# 4      MAC MILLER                           SWIMMING      Evan Rytlewski
#
#    score  releaseyear        reviewdate   recordlabel         genre  \
# 0    8.5       2009.0  February 18 2009        Studio    Electronic
# 1    8.2       2005.0  February 13 2005         Water  Folk/Country
# 2    8.3       2004.0    August 19 2004    In the Red    Electronic
# 3    7.3       2003.0      July 17 2003        Badman          Rock
# 4    7.5       2018.0     August 3 2018  Warner Bros.           Rap
#
#    danceability    energy       key   loudness  speechiness  acousticness  \
# 0      0.511917  0.499667  5.250000  -5.626583     0.031983      0.724917
# 1      0.369765  0.325412  4.470588 -19.153824     0.148624      0.647053
# 2      0.253943  0.912857  4.428571  -1.089500     0.055500      0.000253
# 3      0.425400  0.433474  5.700000 -12.871000     0.028260      0.310325
# 4      0.624846  0.438154  4.153846  -9.456077     0.170246      0.652462
#
#    instrumentalness  liveness   valence       tempo
# 0          0.024493  0.165367  0.555083  101.395167
# 1          0.559133  0.527782  0.179465  107.622647
# 2          0.751214  0.199071  0.552786  133.895500
# 3          0.224137  0.125150  0.451400  104.354200
# 4          0.012819  0.121131  0.281138  122.121308

# %%
# Create a filtered dataframe from specific columns
# Revise dataframe from Zenodo dataset to only include the data columns of 'album', 'score', 'artist', and reviewauthor'.
album_reviews_data_df=album_reviews_all_columns_df[['album','score','artist','reviewauthor']]

# display the contents of the data frame 
album_reviews_data_df.head()
# Out:
#                                album  score          artist  \
# 0                           STUDIO 1    8.5        STUDIO 1
# 1  THE GREAT SANTA BARBARA OIL SLICK    8.2      JOHN FAHEY
# 2                    TOO MUCH GUITAR    8.3  REIGNING SOUND
# 3                     AFTER THE LAST    7.3  THE RED THREAD
# 4                           SWIMMING    7.5      MAC MILLER
#
#          reviewauthor
# 0      Andy Battaglia
# 1     Mark Richardson
# 2  Stephen M. Deusner
# 3        Chris Dahlen
# 4      Evan Rytlewski

# %%
# Review data counts
album_data_df.count()
# Out:
# Release Date        61044
# Artist              61044
# Album               61044
# Track ID            61044
# Track               61044
# Popularity          61044
# Danceability        61044
# Energy              61044
# Key                 61044
# Key Val             61044
# Loudness            61044
# Mode                61044
# Speechiness         61044
# Acousticness        61044
# Instrumentalness    61044
# Liveness            61044
# Valence             61044
# Tempo               61044
# Time Signature      61044
# dtype: int64

# %%
# Review data counts
album_reviews_data_df.count()
# Out:
# album           18403
# score           18403
# artist          18402
# reviewauthor    18403
# dtype: int64

# %%
# Collecting a list of all columns within the DataFrame
album_data_df.columns

#for col in album_data_df:
#    print(col)
# Out:
# Index(['Release Date', 'Artist', 'Album', 'Track ID', 'Track', 'Popularity',
#        'Danceability', 'Energy', 'Key', 'Key Val', 'Loudness', 'Mode',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Time Signature'],
#       dtype='object')

# %%
# Collecting a list of all columns within the DataFrame
album_reviews_data_df.columns
#for columns in album_reviews_data_df:
#    print(columns)
# Out:
# Index(['album', 'score', 'artist', 'reviewauthor'], dtype='object')

# %%
# Rename columns headers in dataframe 
album_reviews_data_df=album_reviews_data_df.rename(columns={"artist":"Artist","album":"Album","reviewauthor":"Review_Author","score":"Score","releaseyear":"Release_Year","reviewdate":"Review_Date","recordlabel":"Record_Label","genre":"Genre","danceability":"Danceability","energy":"Energy","key":"Key","loudness":"Loudness","speechiness":"Speechiness","acousticness":"Acousticness","instrumentalness":"Instrumentalness","liveness":"Liveness","valence":"Valence","tempo":"Tempo"})

# display the contents of the data frame 
album_reviews_data_df.head()
# Out:
#                                Album  Score          Artist  \
# 0                           STUDIO 1    8.5        STUDIO 1
# 1  THE GREAT SANTA BARBARA OIL SLICK    8.2      JOHN FAHEY
# 2                    TOO MUCH GUITAR    8.3  REIGNING SOUND
# 3                     AFTER THE LAST    7.3  THE RED THREAD
# 4                           SWIMMING    7.5      MAC MILLER
#
#         Review_Author
# 0      Andy Battaglia
# 1     Mark Richardson
# 2  Stephen M. Deusner
# 3        Chris Dahlen
# 4      Evan Rytlewski

# %%
# Display data information
album_reviews_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18403 entries, 0 to 18402
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Album          18403 non-null  object
#  1   Score          18403 non-null  float64
#  2   Artist         18402 non-null  object
#  3   Review_Author  18403 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 575.2+ KB

# %% [markdown]
# ## Merge the two DataFrames into a single dataset

# %%
# Create the Final Dataframe - presentation 
# Combine the two datasets (DataFrames) into a single dataset (DataFrame)
#merge_datasets_df=pd.merge(album_reviews_data_df,album_data_df,on="Album")
merge_datasets_df = pd.merge(album_reviews_data_df, album_data_df, on=['Album', 'Artist'])

# display the contents of the data frame 
merge_datasets_df
# Out:
#                  Album  Score          Artist   Review_Author  Release Date  \
# 0             SWIMMING    7.5      MAC MILLER  Evan Rytlewski          2018
# 1             SWIMMING    7.5      MAC MILLER  Evan Rytlewski          2018
# 2             SWIMMING    7.5      MAC MILLER  Evan Rytlewski          2018
# 3             SWIMMING    7.5      MAC MILLER  Evan Rytlewski          2018
# 4             SWIMMING    7.5      MAC MILLER  Evan Rytlewski          2018
# ...                ...    ...             ...             ...           ...
# 4372     BACK IN BLACK    8.8           AC/DC   Steve Kandell          1980
# 4373     BACK IN BLACK    8.8           AC/DC   Steve Kandell          1980
# 4374     BACK IN BLACK    8.8           AC/DC   Steve Kandell          1980
# 4375     BACK IN BLACK    8.8           AC/DC   Steve Kandell          1980
# 4376  HAPPINESS BEGINS    6.2  JONAS BROTHERS    Olivia Horn           2019
#
#                     Track ID                                Track  Popularity  \
# 0     39NDBdU5Xkm5pCFGa5kZtI                              Ladders          73
# 1     01z2fBGB8Hl3Jd3zXe4IXR                   Come Back to Earth          72
# 2     5p7GiBZNL1afJJDUrOA6C8                        Hurt Feelings          71
# 3     2dgrYdgguVZKeCsrVb9XEs                      What's the Use?          70
# 4     0Xcy81PsJCOO6mhLZaQyQ4                             Perfecto          64
# ...                      ...                                  ...         ...
# 4372  5XeMsYb1rWxQL1bUUaZajn          Let Me Put My Love Into You          52
# 4373  2SiXAy7TuUkycRVbbWDEpo          You Shook Me All Night Long          77
# 4374  2MCUmp0I98gsJBmey7DfZS                          Shake a Leg          50
# 4375  6J17MkMmuzBiIOjRH6MOBZ  Rock and Roll Ain't Noise Pollution          60
# 4376  22vgEDb5hykfaTwLuskFGD                               Sucker          86
#
#       Danceability  Energy  ... Key Val  Loudness  Mode  Speechiness  \
# 0            0.802   0.463  ...       8    -8.379     1       0.1620
# 1            0.272   0.238  ...       2   -12.148     0       0.0349
# 2            0.690   0.462  ...       8    -8.054     1       0.1300
# 3            0.759   0.492  ...       1   -10.338     0       0.1200
# 4            0.599   0.317  ...       1   -11.212     1       0.1740
# ...            ...     ...  ...     ...       ...   ...          ...
# 4372         0.400   0.902  ...       9    -4.385     1       0.0523
# 4373         0.532   0.767  ...       7    -5.509     1       0.0574
# 4374         0.417   0.942  ...       4    -4.225     1       0.0852
# 4375         0.576   0.659  ...       9    -5.617     1       0.0383
# 4376         0.842   0.734  ...       1    -5.065     0       0.0588
#
#       Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0          0.23600          0.005310    0.1050    0.291  103.961
# 1          0.89000          0.009250    0.2750    0.119   83.507
# 2          0.34300          0.002180    0.1130    0.325  157.655
# 3          0.73600          0.009890    0.1070    0.561  104.974
# 4          0.74800          0.000000    0.1110    0.203  148.090
# ...            ...               ...       ...      ...      ...
# 4372       0.11500          0.000116    0.1390    0.632  105.659
# 4373       0.00287          0.000513    0.3900    0.755  127.361
# 4374       0.02340          0.008570    0.3170    0.618  152.346
# 4375       0.04100          0.000000    0.0587    0.717   94.853
# 4376       0.04270          0.000000    0.1060    0.952  137.958
#
#       Time Signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 4372               4
# 4373               4
# 4374               4
# 4375               4
# 4376               4
#
# [4377 rows x 21 columns]

# %%
# Review data counts of merged DataFrames
merge_datasets_df.count()
# Out:
# Album               4377
# Score               4377
# Artist              4377
# Review_Author       4377
# Release Date        4377
# Track ID            4377
# Track               4377
# Popularity          4377
# Danceability        4377
# Energy              4377
# Key                 4377
# Key Val             4377
# Loudness            4377
# Mode                4377
# Speechiness         4377
# Acousticness        4377
# Instrumentalness    4377
# Liveness            4377
# Valence             4377
# Tempo               4377
# Time Signature      4377
# dtype: int64

# %% [markdown]
# # Transform - Review/clean the combined DataFrame

# %%
#Save DataFrame to a csv file: /Output_Data/merge_datasets_df_pre_clean.csv
merge_datasets_df.to_csv('Output_Data/1_merge_datasets_df_pre_clean.csv', encoding="utf-8", index="true",header="true")

# %%
# Interrogate dataset
len(merge_datasets_df["Track ID"].unique())
# Out:
# 4352

# %%
# Interrogate dataset
len(merge_datasets_df["Artist"].unique())
# Out:
# 323

# %%
# Interrogate dataset
len(merge_datasets_df["Album"].unique())
# Out:
# 504

# %%
# Interrogate dataset
len(merge_datasets_df["Track"].unique())
# Out:
# 4262

# %%
# Interrogate dataset
merge_datasets_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4372    False
# 4373    False
# 4374    False
# 4375    False
# 4376    False
# Length: 4377, dtype: bool

# %%
# Interrogate dataset - Identify duplicate 'Track ID's.
merge_datasets_df.loc[merge_datasets_df.duplicated("Track ID")== True]
# Out:
#                  Album  Score             Artist     Review_Author  \
# 14   AMERICAN FOOTBALL    7.7  AMERICAN FOOTBALL         Ian Cohen
# 448               1999   10.0             PRINCE  Paul A. Thompson
# 449               1999   10.0             PRINCE  Paul A. Thompson
# 450               1999   10.0             PRINCE  Paul A. Thompson
# 451               1999   10.0             PRINCE  Paul A. Thompson
# 452               1999   10.0             PRINCE  Paul A. Thompson
# 453               1999   10.0             PRINCE  Paul A. Thompson
# 454               1999   10.0             PRINCE  Paul A. Thompson
# 455               1999   10.0             PRINCE  Paul A. Thompson
# 456               1999   10.0             PRINCE  Paul A. Thompson
# 457               1999   10.0             PRINCE  Paul A. Thompson
# 458               1999   10.0             PRINCE  Paul A. Thompson
# 573         THE SLIDER    9.5             T. REX         Andy Beta
# 574         THE SLIDER    9.5             T. REX         Andy Beta
# 575         THE SLIDER    9.5             T. REX         Andy Beta
# 576         THE SLIDER    9.5             T. REX         Andy Beta
# 577         THE SLIDER    9.5             T. REX         Andy Beta
# 578         THE SLIDER    9.5             T. REX         Andy Beta
# 579         THE SLIDER    9.5             T. REX         Andy Beta
# 580         THE SLIDER    9.5             T. REX         Andy Beta
# 581         THE SLIDER    9.5             T. REX         Andy Beta
# 582         THE SLIDER    9.5             T. REX         Andy Beta
# 583         THE SLIDER    9.5             T. REX         Andy Beta
# 584         THE SLIDER    9.5             T. REX         Andy Beta
# 585         THE SLIDER    9.5             T. REX         Andy Beta
#
#      Release Date                Track ID  \
# 14           1999  51R5mPcJjOnfv9lKY1u5sW
# 448          1982  2H7PHVdQ3mXqEHXcvclTB0
# 449          1982  4iozhXt27eMl39W5z7R8H6
# 450          1982  6hazdpTPlt5W2BTCGYKBoj
# 451          1982  31ink8UgWSYUXz0hPasoif
# 452          1982  1YpgRBDgD8ed7eb8i053Qt
# 453          1982  1MpPRotMSsZhI5eevP2qeO
# 454          1982  2hABMU63xtaIYChN6eYlEb
# 455          1982  2dBRAH9J3fL24AJkYmjZno
# 456          1982  3olcbtUJV3xdHIfFjy8owe
# 457          1982  2k96E0L0SY9raNEVMBqbVL
# 458          1982  7AFxCS5OHNvZgD2qceIc5Q
# 573          1972  4KcE3At063Xyleg2xGzVYz
# 574          1972  26QLI0IhoZr7E4Ai0aNkiF
# 575          1972  4mTTEbBeYx2iJGinL3SisU
# 576          1972  4WWUEoRFBOTvb6GwSzvXc8
# 577          1972  4PFYwgDaD9zGD4LdiEyV5Y
# 578          1972  0YSuK8xEcnAhwALeW6fvvq
# 579          1972  79cfk2moyMXtTGZr4N9sWi
# 580          1972  4hdKgDxQMLEoiNwzL1Wu5y
# 581          1972  2ACNE2rAr2pCFUQTp0xdcV
# 582          1972  7rpW9vanJhOhe55YkquixZ
# 583          1972  2PmGtDUyJIpYBEtI1hQIVp
# 584          1972  2n69Fx60rUhDHfVqF1NVKf
# 585          1972  6UlOoWHEF5esnMSGjpAk13
#
#                                          Track  Popularity  Danceability  \
# 14                                 Never Meant          57         0.436
# 448                                       1999          67         0.866
# 449                        Little Red Corvette          53         0.748
# 450                                  Delirious          47         0.920
# 451                Let's Pretend We're Married          32         0.790
# 452                                   D.M.S.R.          35         0.970
# 453                                  Automatic          30         0.830
# 454  Something in the Water (Does Not Compute)          37         0.614
# 455                                       Free          27         0.558
# 456                            Lady Cab Driver          40         0.855
# 457         All the Critics Love U in New York          27         0.838
# 458                        International Lover          39         0.595
# 573                                 Metal Guru          35         0.251
# 574                                Mystic Lady          30         0.444
# 575                                    Rock On          28         0.436
# 576                                 The Slider          33         0.356
# 577                             Baby Boomerang          27         0.529
# 578                         Spaceball Ricochet          27         0.374
# 579                               Buick McCane          27         0.297
# 580                               Telegram Sam          32         0.561
# 581                             Rabbit Fighter          26         0.244
# 582                               Baby Strange          25         0.541
# 583                          Ballrooms Of Mars          34         0.491
# 584                            Chariot Choogle          23         0.292
# 585                                   Main Man          26         0.560
#
#      Energy  ... Key Val  Loudness  Mode  Speechiness  Acousticness  \
# 14    0.819  ...       0    -6.710     1       0.0360      0.017100
# 448   0.730  ...       5    -8.201     1       0.0767      0.137000
# 449   0.746  ...       1    -9.721     1       0.1110      0.281000
# 450   0.402  ...       0   -16.656     1       0.0549      0.058600
# 451   0.455  ...      10   -15.194     0       0.1380      0.003180
# 452   0.499  ...      11    -8.447     1       0.1640      0.066900
# 453   0.422  ...       8   -16.141     1       0.0750      0.040300
# 454   0.415  ...       3   -18.296     0       0.0636      0.095000
# 455   0.459  ...       2   -11.218     1       0.0630      0.376000
# 456   0.502  ...       0   -15.226     1       0.0947      0.044200
# 457   0.269  ...      10   -18.053     0       0.1610      0.000302
# 458   0.277  ...      11   -19.080     1       0.0408      0.138000
# 573   0.917  ...       2    -5.552     1       0.1180      0.000678
# 574   0.641  ...       7    -9.273     1       0.0486      0.003000
# 575   0.801  ...       7    -6.762     1       0.0869      0.046600
# 576   0.566  ...      11    -9.667     0       0.0600      0.000733
# 577   0.899  ...       9    -7.409     1       0.2840      0.004250
# 578   0.363  ...       0    -9.441     1       0.0280      0.259000
# 579   0.928  ...      11    -7.656     0       0.0571      0.000275
# 580   0.897  ...       4    -6.076     0       0.1110      0.045400
# 581   0.778  ...      11    -7.024     0       0.0799      0.012900
# 582   0.541  ...       0    -8.076     1       0.0402      0.035200
# 583   0.606  ...       7   -10.172     1       0.0377      0.003270
# 584   0.853  ...       0    -6.452     1       0.0721      0.016000
# 585   0.511  ...       2    -9.682     1       0.0598      0.012600
#
#      Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 14           0.008820    0.1170    0.405  144.260               4
# 448          0.000000    0.0843    0.625  118.523               4
# 449          0.000033    0.6320    0.709  123.144               4
# 450          0.000434    0.0234    0.957   99.910               4
# 451          0.000104    0.4560    0.819  184.761               4
# 452          0.000010    0.1800    0.740  109.567               4
# 453          0.010400    0.0732    0.902  124.907               4
# 454          0.000169    0.1500    0.725  169.002               4
# 455          0.001810    0.1010    0.520   65.393               4
# 456          0.089800    0.6500    0.749  122.645               4
# 457          0.649000    0.3350    0.915  144.152               4
# 458          0.000171    0.3040    0.440   68.572               4
# 573          0.000453    0.2170    0.504  127.112               4
# 574          0.000000    0.2720    0.496  105.259               4
# 575          0.011800    0.7110    0.638  120.772               4
# 576          0.000003    0.1040    0.573  167.973               4
# 577          0.000004    0.0730    0.611  133.873               4
# 578          0.000000    0.1850    0.391  113.767               4
# 579          0.000137    0.0822    0.738   89.938               4
# 580          0.000000    0.0845    0.422  122.914               4
# 581          0.000000    0.2680    0.524  153.069               3
# 582          0.000000    0.3360    0.870  131.271               4
# 583          0.000008    0.3410    0.669  123.025               4
# 584          0.000000    0.1450    0.484  167.329               4
# 585          0.000000    0.2350    0.429  127.906               4
#
# [25 rows x 21 columns]

# %%
# Interrogate dataset - SORT by 'Album','Artist','Track','Track ID','Score'.

# Sort by multiple columns
merge_datasets_df.sort_values(by=['Album','Artist','Track','Track ID','Score'], inplace=True)

# display the contents of the data frame 
merge_datasets_df
# Out:
#                                   Album  Score             Artist  \
# 1775  (WHAT'S THE STORY) MORNING GLORY?    8.9              OASIS
# 1762  (WHAT'S THE STORY) MORNING GLORY?    8.9              OASIS
# 1772  (WHAT'S THE STORY) MORNING GLORY?    8.9              OASIS
# 1785  (WHAT'S THE STORY) MORNING GLORY?    8.9              OASIS
# 1787  (WHAT'S THE STORY) MORNING GLORY?    8.9              OASIS
# ...                                 ...    ...                ...
# 697                                   Z    7.6  MY MORNING JACKET
# 696                                   Z    7.6  MY MORNING JACKET
# 693                                   Z    7.6  MY MORNING JACKET
# 692                                   Z    7.6  MY MORNING JACKET
# 689                                   Z    7.6  MY MORNING JACKET
#
#            Review_Author  Release Date                Track ID  \
# 1775       Stuart Berman          1995  42qhBnmhRdye0AkG6fguab
# 1762       Stuart Berman          1995  5mhZxnrzzXVNJiy24hLeNj
# 1772       Stuart Berman          1995  7ytT7YUeNBKYdqaRzBE8wc
# 1785       Stuart Berman          1995  0GhjO8IyrfczKpn2iEme5K
# 1787       Stuart Berman          1995  61OmtwKId37JLGmShjRXlj
# ...                  ...           ...                     ...
# 697   Stephen M. Deusner          2005  0aEWcmV1ADdPzvAbvZ9upV
# 696   Stephen M. Deusner          2005  4fikCVxSddXyT4o29KI5id
# 693   Stephen M. Deusner          2005  2LuaCTFQkHilH4a7jGj00J
# 692   Stephen M. Deusner          2005  6sICylTFKeiplGHltWnJ1k
# 689   Stephen M. Deusner          2005  6xAa0kGkTLU22ZyoHOCHgi
#
#                                      Track  Popularity  Danceability  Energy  \
# 1775       Acquiesce (Live At Earls Court)          23         0.311   0.801
# 1762                Acquiesce - Remastered          39         0.208   0.904
# 1772  Bonehead's Bank Holiday - Remastered          29         0.367   0.792
# 1785      Boneheadâ€™s Bank Holiday (Demo)          22         0.340   0.639
# 1787   Cast No Shadow (Live At Maine Road)          23         0.305   0.822
# ...                                    ...         ...           ...     ...
# 697                       Knot Comes Loose          32         0.527   0.263
# 696                                Lay Low          35         0.427   0.835
# 693                         Off The Record          43         0.352   0.654
# 692                   What A Wonderful Man          31         0.422   0.861
# 689                        Wordless Chorus          54         0.824   0.377
#
#       ... Key Val  Loudness  Mode  Speechiness  Acousticness  \
# 1775  ...       0    -3.409     1       0.0602      0.000051
# 1762  ...       7    -4.330     1       0.0810      0.012000
# 1772  ...       7    -5.038     1       0.0969      0.308000
# 1785  ...       7    -7.518     1       0.0306      0.784000
# 1787  ...       0    -5.951     1       0.0396      0.005150
# ...   ...     ...       ...   ...          ...           ...
# 697   ...       5   -10.574     1       0.0242      0.880000
# 696   ...       7    -5.263     1       0.0411      0.152000
# 693   ...       6    -5.868     1       0.0315      0.115000
# 692   ...       9    -4.054     1       0.0485      0.109000
# 689   ...       2    -9.222     1       0.0436      0.107000
#
#       Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 1775          0.055400    0.5950    0.379  121.340               4
# 1762          0.001160    0.3370    0.194  112.125               4
# 1772          0.000000    0.4030    0.533  166.134               4
# 1785          0.002390    0.1730    0.657  176.768               4
# 1787          0.000000    0.3730    0.323   96.281               4
# ...                ...       ...      ...      ...             ...
# 697           0.298000    0.0906    0.191   86.874               4
# 696           0.141000    0.0796    0.445  140.065               4
# 693           0.000213    0.3100    0.509  139.335               4
# 692           0.000025    0.1000    0.596  130.190               4
# 689           0.604000    0.1100    0.779  116.342               4
#
# [4377 rows x 21 columns]

# %%
# Interrogate dataset - SORT by 'Artist','Album','Track','Track ID','Score'.

# Sort by multiple columns
merge_datasets_df.sort_values(by=['Artist','Album','Track','Track ID','Score'], inplace=True)

# display the contents of the data frame 
merge_datasets_df.head()
# Out:
#                              Album  Score     Artist     Review_Author  \
# 1540  PRETTY GIRLS LIKE TRAP MUSIC    8.0   2 CHAINZ  Paul A. Thompson
# 3321       RAP OR GO TO THE LEAGUE    7.6   2 CHAINZ    Sheldon Pearce
# 1966                  I AM > I WAS    7.8  21 SAVAGE  Paul A. Thompson
# 2650                    ISSA ALBUM    6.5  21 SAVAGE    Sheldon Pearce
# 194                WITHOUT WARNING    8.0  21 SAVAGE    Sheldon Pearce
#
#       Release Date                Track ID                      Track  \
# 1540          2017  67gmXPQZL1ISSh13OJJ1Pu                Blue Cheese
# 3321          2019  6Z4rmc0uujCpl8yXe3yjgI  Whip (feat. Travis Scott)
# 1966          2018  4paAidoE8VAemwU4jgCc6l             all my friends
# 2650          2017  2fQrGHiQOvpL9UgPvtYy6G               Bank Account
# 194           2017  7vg47qMIEdLfNdTE3WLf0T                Darth Vader
#
#       Popularity  Danceability  Energy  ... Key Val  Loudness  Mode  \
# 1540          56         0.804   0.583  ...       7    -5.335     1
# 3321          57         0.793   0.399  ...       7    -7.428     1
# 1966          70         0.713   0.620  ...       0    -4.513     1
# 2650          78         0.884   0.346  ...       8    -8.228     0
# 194           56         0.724   0.284  ...       7   -10.494     1
#
#       Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 1540       0.2440        0.0693          0.000000    0.5780   0.1100  130.001
# 3321       0.0951        0.1200          0.000000    0.1240   0.0379  121.949
# 1966       0.0422        0.1710          0.000001    0.1180   0.2060  130.090
# 2650       0.3510        0.0151          0.000007    0.0871   0.3760   75.016
# 194        0.3920        0.5570          0.017500    0.1210   0.1440  150.980
#
#       Time Signature
# 1540               4
# 3321               4
# 1966               4
# 2650               4
# 194                4
#
# [5 rows x 21 columns]

# %%
# Interrogate dataset - SORT by 'Track','Track ID','Artist','Album','Score'.

# Sort by multiple columns
merge_datasets_df.sort_values(by=['Track','Track ID','Artist','Album','Score'], inplace=True)

# display the contents of the data frame 
merge_datasets_df.head()
# Out:
#                            Album  Score               Artist  Review_Author  \
# 3252            ABSOLUTE GARBAGE    5.3              GARBAGE   Adam Moerder
# 790   DOUBLE NICKELS ON THE DIME    9.5            MINUTEMEN   Marc Masters
# 3149             THE EMINEM SHOW    9.1               EMINEM       Ethan P.
# 1311           MASTER OF PUPPETS   10.0            METALLICA  Andy O'Connor
# 3414               69 LOVE SONGS    9.0  THE MAGNETIC FIELDS     Nick Mirov
#
#       Release Date                Track ID  \
# 3252          1995  0P6USuYzHP8GdAyNKLkTZi
# 790           1984  60nriFcKARUpnYksJkDqJR
# 3149          2002  4xkOaSrkexMciUUogZKVTS
# 1311          1986  01ilZoPfh3JyL097Ll6SHN
# 3414          1999  1gDPUTxcq8fnS7kj0uX9aS
#
#                                                   Track  Popularity  \
# 3252                                           #1 Crush          45
# 790                                         #1 Hit Song          34
# 3149                                   'Till I Collapse          83
# 1311  (Anesthesia) - Pulling Teeth (Live at the Arag...          21
# 3414                 (Crazy for You But) Not That Crazy          27
#
#       Danceability  Energy  ... Key Val  Loudness  Mode  Speechiness  \
# 3252         0.635   0.647  ...       7    -7.055     0       0.0235
# 790          0.576   0.820  ...       4    -9.387     1       0.1130
# 3149         0.548   0.847  ...       1    -3.237     1       0.1860
# 1311         0.258   0.674  ...       2   -13.341     1       0.0692
# 3414         0.485   0.838  ...       3    -6.402     1       0.0473
#
#       Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 3252      0.000256           0.00132    0.3580    0.464   94.196
# 790       0.014400           0.73900    0.2000    0.445   91.208
# 3149      0.062200           0.00000    0.0816    0.100  171.447
# 1311      0.893000           0.80200    0.5260    0.291  124.085
# 3414      0.112000           0.19600    0.1480    0.569  134.453
#
#       Time Signature
# 3252               4
# 790                4
# 3149               4
# 1311               4
# 3414               4
#
# [5 rows x 21 columns]

# %%
# Interrogate dataset - SORT by 'Track ID','Track','Artist','Album','Score'.

# Sort by multiple columns
merge_datasets_df.sort_values(by=['Track ID','Track','Artist','Album','Score'], inplace=True)

# display the contents of the data frame 
merge_datasets_df.head()
# Out:
#                        Album  Score                  Artist  \
# 557     BECAUSE THE INTERNET    5.8        CHILDISH GAMBINO
# 2766           TRACY CHAPMAN    9.4           TRACY CHAPMAN
# 932   WHITE LIGHT/WHITE HEAT   10.0  THE VELVET UNDERGROUND
# 1594     SOMETHING/ANYTHING?    9.0           TODD RUNDGREN
# 3379             GOOD NATURE    7.3                TURNOVER
#
#             Review_Author  Release Date                Track ID  \
# 557         Craig Jenkins          2013  00GOPLxW4PGQuUYdPJh8K1
# 2766  Ann-Derrick Gaillot          1988  00OMaIm4VEsUcXad5Pf1Qe
# 932          Douglas Wolk          1968  00bScuvzFpyRMGWlgfu5sp
# 1594         Sam Sodomsky          1972  00f5cJ88kjiyCLJebRHgAY
# 3379            Ian Cohen          2017  00gLuZIDF5bxUEO0RkPx1m
#
#                                      Track  Popularity  Danceability  Energy  \
# 557                         IV. Sweatpants          71         0.710  0.4700
# 2766                       Behind the Wall          46         0.668  0.0505
# 932                Lady Godiva's Operation          34         0.507  0.5300
# 1594  It Wouldn't Have Made Any Difference          34         0.560  0.3920
# 3379                  All That It Ever Was          32         0.614  0.6760
#
#       ... Key Val  Loudness  Mode  Speechiness  Acousticness  \
# 557   ...       1    -9.330     0       0.1420        0.1540
# 2766  ...       5   -18.843     1       0.3580        0.8070
# 932   ...       4   -13.059     0       0.0368        0.7540
# 1594  ...       9   -13.100     1       0.0296        0.2840
# 3379  ...       9    -7.902     1       0.0270        0.0442
#
#       Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 557           0.000000     0.643    0.581   80.027               4
# 2766          0.000000     0.107    0.598  148.649               5
# 932           0.000599     0.143    0.773  114.412               4
# 1594          0.000000     0.074    0.652  172.327               4
# 3379          0.019900     0.112    0.722  130.986               4
#
# [5 rows x 21 columns]

# %%
# Interrogate dataset - SORT by 'Score','Artist','Album','Track ID','Track'.

# Sort by multiple columns
merge_datasets_df.sort_values(by=['Score','Artist','Album','Track ID','Track'], ascending=False, inplace=True)

# display the contents of the data frame 
merge_datasets_df.head()
# Out:
#          Album  Score Artist Review_Author  Release Date  \
# 840  PINK FLAG   10.0   WIRE   Joe Tangari          1977
# 833  PINK FLAG   10.0   WIRE   Joe Tangari          1977
# 839  PINK FLAG   10.0   WIRE   Joe Tangari          1977
# 837  PINK FLAG   10.0   WIRE   Joe Tangari          1977
# 846  PINK FLAG   10.0   WIRE   Joe Tangari          1977
#
#                    Track ID                                     Track  \
# 840  6tPUscoU7EpieQLHBBWd0q  106 Beats That - 2006 Remastered Version
# 833  6ZzgkNscFRe9PiryaeUVwo   Start to Move - 2006 Remastered Version
# 839  6X7CDzfm1Nq7qZwmRaSUWS   Straight Line - 2006 Remastered Version
# 837  6VvpBt95FoPF01YBqv0vV1       Pink Flag - 2006 Remastered Version
# 846  6Slsb9yR7U2gvgw4GEGkbV          Champs - 2006 Remastered Version
#
#      Popularity  Danceability  Energy  ... Key Val  Loudness  Mode  \
# 840          28         0.368   0.878  ...       6    -7.417     0
# 833          35         0.617   0.825  ...      11    -7.147     1
# 839          28         0.455   0.937  ...       2    -5.845     1
# 837          31         0.451   0.844  ...       9    -9.692     1
# 846          29         0.353   0.811  ...       9    -7.224     1
#
#      Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 840       0.0373      0.000787          0.617000    0.2150    0.963  160.314
# 833       0.0591      0.044400          0.000003    0.0398    0.952  103.225
# 839       0.0472      0.576000          0.000071    0.2100    0.685  116.112
# 837       0.0672      0.261000          0.850000    0.1070    0.201  122.168
# 846       0.0403      0.159000          0.000655    0.0579    0.886  169.016
#
#      Time Signature
# 840               4
# 833               4
# 839               4
# 837               4
# 846               4
#
# [5 rows x 21 columns]

# %%
# Interrogate dataset - Resort to ascending based on album

# Sort by multiple columns
merge_datasets_df.sort_index(inplace=True)

# display the contents of the data frame 
merge_datasets_df.head()
# Out:
#       Album  Score      Artist   Review_Author  Release Date  \
# 0  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 1  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 2  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 3  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 4  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
#
#                  Track ID               Track  Popularity  Danceability  \
# 0  39NDBdU5Xkm5pCFGa5kZtI             Ladders          73         0.802
# 1  01z2fBGB8Hl3Jd3zXe4IXR  Come Back to Earth          72         0.272
# 2  5p7GiBZNL1afJJDUrOA6C8       Hurt Feelings          71         0.690
# 3  2dgrYdgguVZKeCsrVb9XEs     What's the Use?          70         0.759
# 4  0Xcy81PsJCOO6mhLZaQyQ4            Perfecto          64         0.599
#
#    Energy  ... Key Val  Loudness  Mode  Speechiness  Acousticness  \
# 0   0.463  ...       8    -8.379     1       0.1620         0.236
# 1   0.238  ...       2   -12.148     0       0.0349         0.890
# 2   0.462  ...       8    -8.054     1       0.1300         0.343
# 3   0.492  ...       1   -10.338     0       0.1200         0.736
# 4   0.317  ...       1   -11.212     1       0.1740         0.748
#
#    Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 0           0.00531     0.105    0.291  103.961               4
# 1           0.00925     0.275    0.119   83.507               4
# 2           0.00218     0.113    0.325  157.655               4
# 3           0.00989     0.107    0.561  104.974               4
# 4           0.00000     0.111    0.203  148.090               4
#
# [5 rows x 21 columns]

# %%
# Clean the data by dropping 'Track ID' duplicates and setting the index
#merge_datasets_df.drop_duplicates('Track ID', inplace=True)
# merge_datasets_df=rename_axis(['Index'])

# %%
# verify counts - validate we now have a clean dataset
merge_datasets_df.count()
# Out:
# Album               4377
# Score               4377
# Artist              4377
# Review_Author       4377
# Release Date        4377
# Track ID            4377
# Track               4377
# Popularity          4377
# Danceability        4377
# Energy              4377
# Key                 4377
# Key Val             4377
# Loudness            4377
# Mode                4377
# Speechiness         4377
# Acousticness        4377
# Instrumentalness    4377
# Liveness            4377
# Valence             4377
# Tempo               4377
# Time Signature      4377
# dtype: int64

# %%
# Display the contents of the clean DataFrame 
merge_datasets_df.head()
# Out:
#       Album  Score      Artist   Review_Author  Release Date  \
# 0  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 1  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 2  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 3  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 4  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
#
#                  Track ID               Track  Popularity  Danceability  \
# 0  39NDBdU5Xkm5pCFGa5kZtI             Ladders          73         0.802
# 1  01z2fBGB8Hl3Jd3zXe4IXR  Come Back to Earth          72         0.272
# 2  5p7GiBZNL1afJJDUrOA6C8       Hurt Feelings          71         0.690
# 3  2dgrYdgguVZKeCsrVb9XEs     What's the Use?          70         0.759
# 4  0Xcy81PsJCOO6mhLZaQyQ4            Perfecto          64         0.599
#
#    Energy  ... Key Val  Loudness  Mode  Speechiness  Acousticness  \
# 0   0.463  ...       8    -8.379     1       0.1620         0.236
# 1   0.238  ...       2   -12.148     0       0.0349         0.890
# 2   0.462  ...       8    -8.054     1       0.1300         0.343
# 3   0.492  ...       1   -10.338     0       0.1200         0.736
# 4   0.317  ...       1   -11.212     1       0.1740         0.748
#
#    Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 0           0.00531     0.105    0.291  103.961               4
# 1           0.00925     0.275    0.119   83.507               4
# 2           0.00218     0.113    0.325  157.655               4
# 3           0.00989     0.107    0.561  104.974               4
# 4           0.00000     0.111    0.203  148.090               4
#
# [5 rows x 21 columns]

# %%
#Save remade data frame to a new csv file: /Output_Data/album_reviews_dataframe.csv
album_reviews_df.to_csv('Output_Data/3_album_reviews_dataframe.csv', encoding="utf-8", index="true",header="true")

# %% [markdown]
# # Create final DataFrame for database creation

# %%
# Create new clean datafrome
album_reviews_df=clean_merge_datasets_df

# display the contents of the data frame 
album_reviews_df.head()
# Out:
#       Album  Score      Artist   Review_Author  Release Date  \
# 0  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 1  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 2  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 3  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
# 4  SWIMMING    7.5  MAC MILLER  Evan Rytlewski          2018
#
#                  Track ID               Track  Popularity  Danceability  \
# 0  39NDBdU5Xkm5pCFGa5kZtI             Ladders          73         0.802
# 1  01z2fBGB8Hl3Jd3zXe4IXR  Come Back to Earth          72         0.272
# 2  5p7GiBZNL1afJJDUrOA6C8       Hurt Feelings          71         0.690
# 3  2dgrYdgguVZKeCsrVb9XEs     What's the Use?          70         0.759
# 4  0Xcy81PsJCOO6mhLZaQyQ4            Perfecto          64         0.599
#
#    Energy  ... Key Val  Loudness  Mode  Speechiness  Acousticness  \
# 0   0.463  ...       8    -8.379     1       0.1620         0.236
# 1   0.238  ...       2   -12.148     0       0.0349         0.890
# 2   0.462  ...       8    -8.054     1       0.1300         0.343
# 3   0.492  ...       1   -10.338     0       0.1200         0.736
# 4   0.317  ...       1   -11.212     1       0.1740         0.748
#
#    Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 0           0.00531     0.105    0.291  103.961               4
# 1           0.00925     0.275    0.119   83.507               4
# 2           0.00218     0.113    0.325  157.655               4
# 3           0.00989     0.107    0.561  104.974               4
# 4           0.00000     0.111    0.203  148.090               4
#
# [5 rows x 21 columns]

# %%
# Display data information for review and setup of database
album_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4377 entries, 0 to 4376
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Album             4377 non-null   object
#  1   Score             4377 non-null   float64
#  2   Artist            4377 non-null   object
#  3   Review_Author     4377 non-null   object
#  4   Release Date      4377 non-null   int64
#  5   Track ID          4377 non-null   object
#  6   Track             4377 non-null   object
#  7   Popularity        4377 non-null   int64
#  8   Danceability      4377 non-null   float64
#  9   Energy            4377 non-null   float64
#  10  Key               4377 non-null   object
#  11  Key Val           4377 non-null   int64
#  12  Loudness          4377 non-null   float64
#  13  Mode              4377 non-null   int64
#  14  Speechiness       4377 non-null   float64
#  15  Acousticness      4377 non-null   float64
#  16  Instrumentalness  4377 non-null   float64
#  17  Liveness          4377 non-null   float64
#  18  Valence           4377 non-null   float64
#  19  Tempo             4377 non-null   float64
#  20  Time Signature    4377 non-null   int64
# dtypes: float64(10), int64(5), object(6)
# memory usage: 752.3+ KB

# %%
# Display data types and review
album_reviews_df.dtypes
# Out:
# Album                object
# Score               float64
# Artist               object
# Review_Author        object
# Release Date          int64
# Track ID             object
# Track                object
# Popularity            int64
# Danceability        float64
# Energy              float64
# Key                  object
# Key Val               int64
# Loudness            float64
# Mode                  int64
# Speechiness         float64
# Acousticness        float64
# Instrumentalness    float64
# Liveness            float64
# Valence             float64
# Tempo               float64
# Time Signature        int64
# dtype: object

# %% [markdown]
# ## Connect to local database

# %%
# Launch Postgres PG Admin4 and create PostgreSQL database called 'album_db'. Then run this command string.
# connection_string = "<insert user name>:<insert password>@localhost:5432/album_db"
connection_string = "postgres:postgres@localhost:5432/album_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables (no data exists at this time...load data into db)
engine.table_names()
# Out:
# ['Album_db']

# %% [markdown]
# ## Load DataFrame into database (postgreSQL)

# %%
# Use pandas to load csv converted DataFrame into database
album_reviews_df.to_sql(name='Album_db', con=engine, if_exists='', index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-307f41389017> in <module>
#       1 # Use pandas to load csv converted DataFrame into database
# ----> 2 album_reviews_df.to_sql(name='Album_db', con=engine, if_exists='', index=True)
#
# ~\anaconda\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     499     """
#     500     if if_exists not in ("fail", "replace", "append"):
# --> 501         raise ValueError(f"'{if_exists}' is not valid for if_exists")
#     502
#     503     pandas_sql = pandasSQL_builder(con, schema=schema)
#
# ValueError: '' is not valid for if_exists

# %%
# Confirm tables (data exists at this time...)
engine.table_names()

# Confirm data has been added by querying the customer_name table
# NOTE: can also check using pgAdmin

# %%
album_db.read_sql_query('select * from Album', con=engine).head()

# %% [markdown]
# ## Load DataFrame into database (SQLite)

# %%
## Import SQL Alchemy
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy

## SQL Alchemy Configuration Parameters 
# automap_base required for Reflection...
from sqlalchemy.ext.automap import automap_base  

from sqlalchemy.orm import Session
#from sqlalchemy import create_engine, func

# inspect required for Inspection...
from sqlalchemy import create_engine, func

# %%
# Path to sqlite
album_database_path = "./Output_Data/album_reviews.sqlite"

# Create an engine that can talk to the database
#engine = create_engine("sqlite:///Resources/hawaii.sqlite")
engine = create_engine(f"sqlite:///{album_database_path}")

# To enable Pandas and create a DataFrame
connect = engine.connect()

# %%
# Confirm tables (data exists at this time...)
engine.table_names()

# %% [markdown]
# ## -- EOF -- ##
